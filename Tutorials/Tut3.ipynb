# %%
class Car:
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year
    
    def info(self):
        print(f"Make: {self.make}\nModel: {self.model}\nYear: {self.year}")

# %%
new_car = Car("Acharya Electronics", 'DavidPutra', '2026')
new_car.info()
# Out:
# Make: Acharya Electronics
# Model: DavidPutra
# Year: 2026

# %%
class ElectircCar(Car):
    def __init__(self, make, model, year, battery_capacity):
        super().__init__(make, model, year)
        self.battery_capacity = battery_capacity
    
    def info(self):
        super().info()
        print(f"Battery Capacity: {self.battery_capacity}")

# %%
elec_car = ElectircCar("Acharya Electronics", "SuryaPutra", '2025', "100 km per 100%")
elec_car.info()
# Out:
# Make: Acharya Electronics
# Model: SuryaPutra
# Year: 2025
# Battery info: 100 km per 100%

# %%
class Rectangle:
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width
    
    def perimeter(self):
        return 2 * (self.length + self.width)

rect = Rectangle(10,20)
print(f"Area: {rect.area()}")
print(f"Perimeter: {rect.perimeter()}")
# Out:
# Area: 200
# Perimeter: 60

# %%
class Circle:
    def __init__(self, radius):
        self.__radius = radius
    
    def get_radius(self):
        return self.__radius
    
    def set_radius(self, rad):
        self.__radius = rad
    
    def display(self):
        print(f"radius: {self.__radius}")

    def area(self):
        return 3.1415 * (self.__radius) ** 2

cir = Circle(6)
print(f"Radius is {cir.area()}")
# Out:
# Radius is 113.09400000000001

# %%
class BankAccount:
    def __init__(self, amount):
        self.__amount = amount
    
    def deposit(self, amount):
        self.__amount += amount
        print(f"Rs. {amount} deposited to your account.")
    
    def withdraw(self, amount):
        if self.__amount < amount:
            raise Exception("You dont have enough balance for this transaction!")
        
        self.__amount -= amount
        print(f"Rs. {amount} withdrawn from your account.")

    def check_balance(self):
        print(f"You have Rs {self.__amount} in you account.")

my_account = BankAccount(200000)
my_account.check_balance()
my_account.deposit(10000)
my_account.check_balance()
my_account.withdraw(10000)
my_account.check_balance()
my_account.withdraw(300000)
# Out:
# You have Rs 200000 in you account.
# Rs. 10000 deposited to your account.
# You have Rs 210000 in you account.
# Rs. 10000 withdrawn from your account.
# You have Rs 200000 in you account.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[18], line 25
#      23 my_account.withdraw(10000)
#      24 my_account.check_balance()
# ---> 25 my_account.withdraw(300000)
#
# Cell In[18], line 11, in BankAccount.withdraw(self, amount)
#       9 def withdraw(self, amount):
#      10     if self.__amount < amount:
# ---> 11         raise Exception("You dont have enough balance for this transaction!")
#      13     self.__amount -= amount
#      14     print(f"Rs. {amount} withdrawn from your account.")
#
# Exception: You dont have enough balance for this transaction!
