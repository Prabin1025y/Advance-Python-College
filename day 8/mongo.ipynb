# %%
from pymongo import MongoClient

# URI to connect to database
uri = "mongodb+srv://pujanneupaneop0907_db_user:rvvAy7qDnXFz14ax@cluster0.rcodpuy.mongodb.net/?appName=Cluster0"

client = MongoClient(uri)
db = client['School'] #Database name
collection = db['students_prabin'] #

# %%
print(client.list_database_names())

# %%
many_students = [
    {"name": "Prabin", "age":18, "subjects":["Math", "Science"]},
    {"name":"Shyam", "age": 27, "subjects":["Math", "Science"]}
]

# Insert many data at once
collection.insert_many(many_students)

# %%
# To query data we use find method
for data in collection.find():
    print(data)

# %%
# to query with condition, we pass arguments to find function
# this condition means fetch data where age is greater than 20
result = collection.find({"age": {"$gt": 20}})
for data in result:
    print(data)

# %%
# to update data in collection
collection.update_one()

# %%
# to drop a collection
collection.drop()
print(db.list_collection_names())
