# %%
import numpy as np
import pandas as pd

# %%
X = np.random.random(2000)
df = pd.DataFrame({"X": X})
print("Kurtosis of X column", df['X'].kurt())
# Out:
# Kurtosis of X column -1.1860639132390927

# %% [markdown]
# ## Hypothesis Testing

# %%
import numpy as np

observed = np.array([
    [250, 200],
    [50, 1000]
])

# %%
from scipy.stats import chi2_contingency

chi2, p, dof, exp = chi2_contingency(observed, correction=False)

print(f"Chi-square: {chi2:.4f}")
print(f"p-value: {p:.6f}")
print(f"Degrees of freedom: {dof}")
print(f"Expected Values: {exp}")
# Out:
# Chi-square: 507.9365
# p-value: 0.000000
# Degrees of freedom: 1
# Expected Values: [[ 90. 360.]
#  [210. 840.]]
